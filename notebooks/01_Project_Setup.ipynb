# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
print("Retail Lakehouse Project Started")
# Out:
# Retail Lakehouse Project Started

# %%
project_path = "/content/drive/MyDrive/retail-lakehouse"

print(project_path)
# Out:
# /content/drive/MyDrive/retail-lakehouse

# %%
project_path + "/raw"
# Out:
# '/content/drive/MyDrive/retail-lakehouse/raw'

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'retail-lakehouse',
#  'photo 4.JPG',
#  'Google Photos',
#  'IMG_20170603_111455.jpg',
#  '1525778373779.jpg',
#  '1525778467271.jpg',
#  'New Doc 2018-05-08.jpg',
#  '1525778604443.jpg',
#  '1525778654430.jpg',
#  '1525778838154.jpg',
#  '1525778944289.jpg',
#  'Coursera PythonForDataScienceAndAI.pdf',
#  'Coursera GBSGZTR2YPLV.pdf',
#  'Immigration Documents',
#  'Harshil Documents',
#  'Payment  Details .gsheet',
#  'Original Documents ',
#  'GOVERNMENT OF GUJARAT.pdf',
#  'File_000',
#  'Harshil Patel_Biodata.pdf',
#  'Harshil Patel_Resume 1.pdf',
#  "Harshil Alberta DRIVER'S LICENCE.pdf"]
